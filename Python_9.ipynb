# %%
#Name : Surabhi Sawaleshwarkar
#Roll No. : 9130

# %% [markdown]
# # Content
# * Libraries
# * Barplot (Simple, multiple, sub-divided)
# * Pie chart
# * Histogram
# * Density plot
# * Boxplot
# * Scatterplot

# %%
## Libraries
import numpy as np              # For data arrays
import pandas as pd             # For data frames
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/surabhi-gs/Basics-of-Python_SPC/main/Attrition1.csv')
print(df.head())
# Out:
#    Unnamed: 0  Age  Attrition     BusinessTravel  DailyRate  \
# 0           0   41          1      Travel_Rarely       1102
# 1           1   49          0  Travel_Frequently        279
# 2           2   37          1      Travel_Rarely       1373
# 3           3   33          0  Travel_Frequently       1392
# 4           4   27          0      Travel_Rarely        591
#
#                Department  DistanceFromHome EducationField  Gender  \
# 0                   Sales                 1  Life Sciences  Female
# 1  Research & Development                 8  Life Sciences    Male
# 2  Research & Development                 2          Other    Male
# 3  Research & Development                 3  Life Sciences  Female
# 4  Research & Development                 2        Medical    Male
#
#    HourlyRate  ... MonthlyIncome  NumCompaniesWorked  OverTime  \
# 0          94  ...          5993                   8       Yes
# 1          61  ...          5130                   1        No
# ...

# %% [markdown]
# # **The Pandas Plot Function**
# Pandas has a built in .plot() function as part of the DataFrame class. It has several key parameters:
#
# * kind — ‘bar’,’barh’,’pie’,’scatter’,’kde’ etc.
# * color — Which accepts and array of hex codes corresponding sequential to each data series / column.
# * linestyle — ‘solid’, ‘dotted’, ‘dashed’ (applies to line graphs only)
# * xlim, ylim — specify a tuple (lower limit, upper limit) for which the plot will be drawn
# * legend— a boolean value to display or hide the legend
# * labels — a list corresponding to the number of columns in the dataframe, a descriptive name can be provided here for the legend
# * title — The string title of the plot

# %%
# Bar chart for Business travel
# colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral','red','green','blue','orange','white','brown']
var=df['BusinessTravel'].value_counts()
print(var)
var.plot(kind='bar',title='Bar plot for Business Travel',color='lightskyblue')
#var.plot.bar(title='Bar plot for Business Travel')
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
var=df['BusinessTravel'].value_counts()/df.shape[0]*100
print(var)
var.plot(kind='bar',title='Bar plot for Business Travel')
#var.plot.bar(title='Bar plot for Business Travel')
# Out:
# Travel_Rarely        70.952381
# Travel_Frequently    18.843537
# Non-Travel           10.204082
# Name: BusinessTravel, dtype: float64

# %%
var=df['BusinessTravel'].value_counts()
print(var)
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
var.index
# Out:
# Index(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype='object')

# %%
var.plot.bar(title='Bar plot for Business Travel',color=['pink','purple','blue'])

# %%
var.plot.bar(title='Bar plot for Business Travel',color=['pink','purple','blue'], ylim=[0,1400])

# %%
var.plot.bar(title='Bar plot for Business Travel',color=['pink','purple','blue'], ylim=[0,1200],legend=True)

# %%
var.plot.barh(title='Bar plot for Business Travel',color='pink') #barh for horizontal

# %%
var.plot.barh(title='Bar plot for Business Travel',color=['pink','purple','blue'],xlim=[0,1200],legend=True)

# %%
t1=pd.crosstab(df.BusinessTravel,df.Gender)#.T
t1
# Out:
# Gender             Female  Male
# BusinessTravel
# Non-Travel             49   101
# Travel_Frequently     117   160
# Travel_Rarely         422   621

# %%
t1.plot.bar(title='Multiple bar plot',color=['pink','purple'],ylim=[0,700],legend=True)

# %%
t1.plot.bar(stacked=True,title='Sub-divided bar plot',color=['pink','purple'],ylim=[0,1200],legend=True)

# %%
t1.T.plot.bar(stacked=True,title='Sub-divided bar plot',color=['pink','purple','blue'],ylim=[0,1500],legend=True)

# %%
# Pie chart for Business travel
#var.plot(kind='pie',title='Pie chart for Business Travel')
var.plot.pie(title='Pie chart for Business Travel',legend=False)

# %%
JR=df['JobRole'].value_counts()
print(JR)
JR.plot.pie(title='Pie chart for JobRole',legend=False)
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
# Histogram for Age
df.Age.plot.hist(color='pink',title='Histogram for Age')#, bins = 20)

# %%
df.YearsAtCompany.plot.hist(title='Hist for YearsAtCompany',color='purple')

# %%
# KDE for Age
df.Age.plot.kde(color='blue',title='Density for Age',linestyle='dashed') # solid dotted

# %%
# KDE for years@compasny
df.YearsAtCompany.plot.kde(color='pink',title='Density for YearsAtCompany',linestyle='solid') # solid dotted

# %%
df.Age.plot.box(color='purple',title='Boxplot for Age')

# %%
df.YearsAtCompany.plot.box(color='blue',title='Boxplot for YearsAtCompany')

# %%
# Scatterplot for Age and MonthlyIncome
df.plot.scatter(x='Age',y='MonthlyIncome',color='lightcoral',title='Scatter plot for Age and Income')

# %%
# Scatterplot for Age and MonthlyIncome
df.plot.scatter(x='Age',y='YearsAtCompany',color='green',title='Scatter plot for Age and YearsAtCompany')

# %%
# Scatterplot for Age and MonthlyIncome
df.plot.scatter(x='PercentSalaryHike',y='Age',color='orange',title='Scatter plot for Age and Income')
